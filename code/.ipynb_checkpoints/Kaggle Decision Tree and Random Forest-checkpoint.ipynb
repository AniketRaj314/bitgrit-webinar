# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
url = 'melb_data.csv'
data = pd.read_csv(url)
data = data.dropna(axis=0)

# %%
y = data.Price
features = ['Rooms', 'Lattitude', 'Longtitude', 'YearBuilt', 'Landsize', 'BuildingArea']
X = data[features]

# %%
def build(nodes):
    model = DecisionTreeRegressor(max_leaf_nodes = nodes, random_state=1)
    model.fit(trainX, trainY)
    return model

# %%
def build2(nodes):
    model = RandomForestRegressor(max_leaf_nodes = nodes, random_state = 1)
    model.fit(trainX, trainY)
    return model

# %%
mae = []
x_axis = [i for i in range(2, 10009)]
trainX, valX, trainY, valY = train_test_split(X, y, random_state = 1)
for x in x_axis:
    model = build(x)
    predict = model.predict(valX)
    mae.append(mean_absolute_error(predict, valY))
    print(f"TEST no. {x} completed!")
    
print("ready")
# Out:
# TEST no. 2 completed!
# TEST no. 3 completed!
# TEST no. 4 completed!
# TEST no. 5 completed!
# TEST no. 6 completed!
# TEST no. 7 completed!
# TEST no. 8 completed!
# TEST no. 9 completed!
# TEST no. 10 completed!
# TEST no. 11 completed!
# TEST no. 12 completed!
# TEST no. 13 completed!
# TEST no. 14 completed!
# TEST no. 15 completed!
# TEST no. 16 completed!
# TEST no. 17 completed!
# TEST no. 18 completed!
# TEST no. 19 completed!
# TEST no. 20 completed!
# TEST no. 21 completed!
# TEST no. 22 completed!
# TEST no. 23 completed!
# TEST no. 24 completed!
# TEST no. 25 completed!
# TEST no. 26 completed!
# TEST no. 27 completed!
# TEST no. 28 completed!
# TEST no. 29 completed!
# TEST no. 30 completed!
# TEST no. 31 completed!
# TEST no. 32 completed!
# TEST no. 33 completed!
# TEST no. 34 completed!
# TEST no. 35 completed!
# TEST no. 36 completed!
# TEST no. 37 completed!
# TEST no. 38 completed!
# TEST no. 39 completed!
# TEST no. 40 completed!
# TEST no. 41 completed!
# ...

# %%
plt.grid()
a = 3407
b = 920
plt.plot(x_axis, mae)
print(x_axis[a], mae[a])
#therefore, best max_leaf_nodes(DT) = 137
#therefore, best max_leaf_nodes(RF) = 903
print(f"Best Max-Leaf-Nodes value = {x_axis[mae.index(min(mae))]}, as corresponding minimum cost = {min(mae)}")
print(f"Worst Max-Leaf-Nodes value after best= {x_axis[mae.index(max(mae[mae.index(min(mae)):]))]}, as corresponding minimum cost = {max(mae[mae.index(min(mae)):])}")
# Out:
# 3409 259895.8205293738
# Best Max-Leaf-Nodes value = 137, as corresponding minimum cost = 237618.22275440264
# Worst Max-Leaf-Nodes value after best= 3409, as corresponding minimum cost = 259895.8205293738
